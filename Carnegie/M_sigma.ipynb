# %%
import h5py
import matplotlib.pyplot as plt
import numpy as np
from astropy.io import ascii
from astropy.table import Table
import pandas as pd

# %%
mass_bh=np.array([4.1,3.9,1.4,1.7, 2.8, 2.6,1.4, 8.6, 1.7, 4,
         6.8,7.1,1.7,1.5, 5.9, 5.1,1.3, 4.7, 3.9, 7.8,
         1.4,4.1,1.21,8,3.7,8.9,1.5,2.1,7.6,1.8,
         4.2,1.1,3.3,6,3.3,1.4,4.7,9.7,8.5,1.8,
         3.67,5.3,9.8,4.6,9.2,8.8,7,2.5,8.9,6.2,
         1.4,8.8,6.7,8.4,4.7,2,6.8,1.6,2.1,8,
         5.9,4,1.7,4.9,3.8,6,3.03,9.8,4,5.5,
         2.3,1.3,1.08])



massp=np.array([0.6,0.4,0.3,0.4,1.1,0.5,0.8,1.0,0.7,0.4,
      0.3,3.4,0.3,0.2,0.6,0.6,0.5,0.7,0.7,0.4,
      0.1,0.4,0.05,2,0.1,5.1,0.5,0.5,1.6,0.9,
      1,.5,.2,.8,1.5,.4,1,3,.7,.6,
      .01,1.1,3.1,2.6,1,.2,1.3,.6,4.5,.3,
       0.5,2.4,0.5,3.6,1.1,.2,1.6,.4,1.6,5,
       1.1,0.1,.3,1.5,1.7,2,.05,.1,2.8,1.6,
       1.2,.5,.06
      ])

massm=np.array([0.6,0.6,0.2,0.3,1.2,0.5,0.3,0.4,0.7,0.4,
      0.3,1.8,0.3,0.2,0.5,0.7,0.7,0.5,0.7,0.4,
      0.4,0.5,.05,1.1,0.5,2.7,0.8,0.6,1.5,0.9,
      1.1,.5,.2,.9,0.6,.5,1,2.5,.7,.3,
      .01,1.1,3.1,1.5,.8,.2,1.4,.1,4.4,.4,
      0.5,2.4,.4,2.5,1,.2,1.6,.4,1.55,3.3,
       1,1.1,.4,1.6,1.2,2,.04,.1,1.6,1.1,
       .1,.4,.05
      ])


vdis_errp=[20,14,16,18,16,3,8,12,10,10,
           26,10,11,16,9,15,15,14,14,15,
           7,9,16,7,15,11,12,10,28,7,
           10,7,10,15,10,11,9,14,14,9,
           10,15,12,11,14,8,8,15,9,28,
           5,8,12,6,17,8,6,5,17,11,
           7,26,9,11,16,14,16,28,13,19,
           16,13,13
        ]
vdis_errm=[20,14,16,18,16,3,8,12,10,10,
           22,10,11,16,9,15,15,14,14,15,
           7,9,15,7,15,11,12,10,24,7,
           10,7,10,11,10,11,9,14,14,9,
           10,15,12,11,14,7,8,15,9,16,
           5,8,12,6,17,8,6,5,17,11,
           7,26,9,11,16,14,14,23,13,19,
           16,13,12
          ]

# %%
power=np.array([1e6,1e9,1e9,1e6,1e9,1e6,1e8,1e8,1e8,1e7,
       1e7,1e7,1e8,1e9,1e8,1e8,1e9,1e9,1e9,1e6,
       1e7,1e7,1e7,1e7,1e9,1e8,1e7,1e8,1e6,1e8,
       1e8,1e7,1e7,1e6,1e8,1e8,1e8,1e9,1e8,1e8,
       1e7,1e8,1e8,1e8,1e8,1e6,1e7,1e9,1e7,1e9,
       1e7,1e7,1e8,1e7,1e9,1e8,1e6,1e6,1e10,1e8,
       1e7,1e9,1e8,1e8,1e9,1e8,1e7,1e6,1e8,1e7,
       1e9,1e9,1e7
       
      ])

vdispersion=[103,288,322,158,315,75,160,235,209,205,
             148,218,226,328,174,296,296,274,289,144,
             145,189,166,143,307,230,133,205,122,145,
             206,143,148,100,213,229,182,270,272,180,
             115,315,242,225,296,107,167,300,190,324,
             111,162,230,136,341,177, 112, 96,347,222,
             150,306,183,234,318,290,158,158,266,156,
             313,257,107]

# %%
print(len(massp),len(massm))
print(len(vdis_errp),len(vdis_errm))
# Out:
# 73 73
# 73 73

# %%
print(len(mass_bh),len(vdispersion))
# Out:
# 73 73

# %%
line=0
# print(data.loc[:,0][line])
print(len(data))
for line in range(30,40):
    print(data.loc[:,0][line])
#     print(data.loc[:,0][line][12:16],data.loc[:,0][line][32:37])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/8_/c96bc5xx7ps75wmdbb1vl_z40000gn/T/ipykernel_29282/536603396.py in <module>
#       1 line=0
#       2 # print(data.loc[:,0][line])
# ----> 3 print(len(data))
#       4 for line in range(30,40):
#       5     print(data.loc[:,0][line])
#
# NameError: name 'data' is not defined

# %%
f = open('Msigma.txt', 'r')

# %%
1.1,.5,.2,.9,0.6,.5,1,2.5,.7,.3
# Out:
# (1.1, 0.5, 0.2, 0.9, 0.6, 0.5, 1, 2.5, 0.7, 0.3)

# %%
#Galacticus file
# name='emissionLines_1000_mass3e13_SFR_MresScaled2-5e9_bpt_z0_Gunawardhana2013_vdisSph_mY0-04_BH_hothalo1.hdf5'
name='emissionLines_1000_mass3e13_SFR_MresScaled2-5e9_bpt_z0_Gunawardhana2013_vdisSph_mY0-04_R0-6.hdf5'
# name='emissionLines_1000_mass3e13_SFR_MresScaled2-5e9_bpt_z0_Gunawardhana2013_vdisSph_mY0-04_R0-6_BH_sph3.hdf5'
file=h5py.File(name,'r')

#merger tree weight
w=file['Outputs']['Output1']['nodeData']['mergerTreeWeight'][:]

# %%
BHmass=file['Outputs']['Output1']['nodeData']['blackHoleMass'][:]
vdis=file['Outputs']['Output1']['nodeData']['velocityDispersion'][:]
mass=file['Outputs']['Output1']['nodeData']['basicMass'][:]

# %%
print(vdis)
# Out:
# [[ 0.        ]
#  [31.35179674]
#  [ 0.        ]
#  ...
#  [ 0.        ]
#  [ 0.        ]
#  [ 0.        ]]

# %%
# print(vdis[i])
SFR=file['Outputs']['Output1']['nodeData']['spheroidStarFormationRate'][:]+file['Outputs']['Output1']['nodeData']['diskStarFormationRate'][:]
mask=SFR>=1e8

# %%
print(w[mask])
# Out:
# [3.23100102e-07 3.23100102e-07 3.20106012e-07 ... 6.48581311e-05
#  6.54063333e-05 5.90978800e-05]

# %%
velocityDispersion=[]
for i in range(len(vdis)):
    velocityDispersion.append(vdis[i][0])

# %%
x=np.linspace(5,400,200)
fig=plt.figure(figsize=(10,10))
ax=fig.add_subplot(111)

import matplotlib as mpl
ax.errorbar(vdispersion,mass_bh*power,xerr=[vdis_errp,vdis_errm],yerr=[power*massp,power*massm],color='k',fmt='o',alpha=0.4)
# ax.scatter(vdispersion,mass_bh*power,s=30,c='k',alpha=0.5,marker='o')
# ax.hist2d(np.array(velocityDispersion),BHmass,bins=(np.logspace(-1,2.5,120),np.logspace(1.5,11,120)),weights=w,norm=mpl.colors.LogNorm(),cmap='GnBu',alpha=.8,label='Galacticus')
sc=ax.hist2d(np.array(velocityDispersion)[mask],BHmass[mask],bins=(np.logspace(-1,2.5,120),np.logspace(1.5,11,120)),weights=w[mask],norm=mpl.colors.LogNorm(),cmap='GnBu',alpha=1,label='Galacticus (SFR>1e8 M/Gyrs)')

# norm = mpl.colors.Normalize(vmin=0, vmax=100)
# plt.scatter(vdis,BHmass,s=10)

ax.plot(x,10**8.32*1.9*((x/200)**5.64),c='k',ls='--',label='All galaxies (McConnell & Ma 2013)')

# ax.plot(x,(10**8.12)*1.9*((x/200)**4.24),c='grey',ls='--',label='Gultekin+2009')

ax.axvline(200,c='grey',ls=':')
# ax.scatter(np.array(velocityDispersion),np.array(velocityDispersion)**5,c='grey',s=1)
ax.text(15,1e10,r'$\frac{\mathrm{M}_{BH}}{10^{8.32}\,M_{\odot}}\sim 1.9 {({\frac{\sigma_*}{200\,km/s}})}^{5.64}$',fontsize=15,c='k')
# ax.text(100,5e8,r'$\frac{\mathrm{M}_{BH}}{10^{8.12}\,M_{\odot}}\sim 1.9 {({\frac{\sigma_*}{200\,km/s}})}^{4.24}$',fontsize=15,c='grey')
ax.set_ylim(1e3,1e11)
ax.set_xlim(10,400)
# ax.set_xticks(np.linspace(50,200,50))
ax.set_yscale('log')
ax.set_xscale('log')
# ax.set_facecolor('k')
ax.set_xlabel(r'$\sigma_*\,[\mathrm{km/s}]$',size=20)
ax.set_ylabel(r'$\mathrm{M}_{\mathrm{BH}}\,[\mathrm{M}_{\odot}]$',size=20)
ax.tick_params(axis='both', which='major', labelsize=14)
ax.legend(fontsize=15)
fig.savefig('figures/M_sigma_R0-6.png')

# %%
fig1=plt.figure(figsize=(10,10))
ax1=fig1.add_subplot(111)

import matplotlib as mpl
# ax1.hist2d(np.array(velocityDispersion),BHmass,bins=(np.logspace(-1,2.5,120),np.logspace(1.5,11,120)),weights=w,norm=mpl.colors.LogNorm(),cmap='GnBu',alpha=.5,label='Galacticus')
sc=ax1.hist2d(mass[mask],np.array(velocityDispersion)[mask],bins=(np.logspace(9,14,120),np.logspace(-1,2.5,150)),weights=w[mask],c=np.log10(BHmass[mask]),vmin=5,vmax=10,cmap='viridis',alpha=.6,label='Galacticus (SFR>1e8 M/Gyrs)')

# norm = mpl.colors.Normalize(vmin=0, vmax1=100)
# plt.scatter(vdis,BHmass,s=10)

# ax1.plot(x,1e8*1.9*((x/200)**5.1),c='grey',ls='--')

# ax1.plot(x,(10**8.12)*1.9*((x/200)**4.24),c='k',ls='--',label='Gultekin+2009')

ax1.axvline(2.5e9,c='grey',ls=':')
# ax1.scatter(np.array(velocityDispersion),np.array(velocityDispersion)**5,c='grey',s=1)
ax1.text(3e9,20,r'$M_{res}=2.5\times10^9\,M_{\odot}$',fontsize=15,c='grey')
# ax1.text(100,5e8,r'$\frac{\mathrm{M}_{BH}}{10^8.12\,M_{\odot}}\sim 1.9 {({\frac{\sigma_*}{200\,km/s}})}^{4.24}$',fontsize=15,c='k')
ax1.set_xlim(1e9,1e14)
ax1.set_ylim(10,400)
# ax1.set_xticks(np.linspace(50,200,50))
ax1.set_yscale('log')
ax1.set_xscale('log')
# ax1.set_facecolor('k')
ax1.set_ylabel(r'$\sigma_*\,[\mathrm{km/s}]$',size=20)
ax1.set_xlabel(r'$\mathrm{M}_{\mathrm{DM}}\,[\mathrm{M}_{\odot}]$',size=20)
ax1.tick_params(axis='both', which='major', labelsize=14)
ax1.legend(fontsize=15)
# Out:
# /var/folders/8_/c96bc5xx7ps75wmdbb1vl_z40000gn/T/ipykernel_62629/365561676.py:6: RuntimeWarning: invalid value encountered in log10
#   sc=ax1.hist2d(mass[mask],np.array(velocityDispersion)[mask],bins=(np.logspace(9,14,120),np.logspace(-1,2.5,150)),weights=w[mask],c=np.log10(BHmass[mask]),vmin=5,vmax=10,cmap='viridis',alpha=.6,label='Galacticus (SFR>1e8 M/Gyrs)')
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/8_/c96bc5xx7ps75wmdbb1vl_z40000gn/T/ipykernel_62629/365561676.py in <module>
#       4 import matplotlib as mpl
#       5 # ax1.hist2d(np.array(velocityDispersion),BHmass,bins=(np.logspace(-1,2.5,120),np.logspace(1.5,11,120)),weights=w,norm=mpl.colors.LogNorm(),cmap='GnBu',alpha=.5,label='Galacticus')
# ...

# %%
fig1.savefig('figures/sigma_Mass.png')
